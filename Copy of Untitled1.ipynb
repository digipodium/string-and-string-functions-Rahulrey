# %%
name='my name is rahul sarkar'

# %%
name
# Out:
# 'my name is rahul sarkar'

# %%
len(name)
# Out:
# 23

# %%
word='python is great'
word[10:15]
# Out:
# 'great'

# %%
quote='python is everywhere'
for word in quote.split():
  print(word)
# Out:
# python
# is
# everywhere

# %%
name='hello world'
name[::-1]
# Out:
# 'dlrow olleh'
# 'dlrow olleh'

# %%
words="How are you"
print(words.upper())
# Out:
# HOW ARE YOU

# %%
name="How is it going"
print(name.lower())
# Out:
# how is it going

# %%
words=['python','is','easy','to','learn']
print(''.join(words),end='')
# Out:
# pythoniseasytolearn

# %%
a="""there was a dog who was,
loyal to his master and his master 
did not care for him."""
print(a)
# Out:
# there was a dog who was,
# loyal to his master and his master
# did not care for him.

# %%
s = input()
for w in s:
  print(w)
# Out:
# rahul
# r
# a
# h
# u
# l

# %%
s = input()
print(s.endswith('?'))
# Out:
# rahul?
# True

# %%
s = input()
print(s.count('e'))
# Out:
# aeroplane
# 2

# %%
s = input()
print(type(int(s))
# Out:
# 1234
# <class 'int'>

# %%
s = '   this is not a good string           '
print(s.strip())
# Out:
# this is not a good string

# %%
s = "Rahul"
flag  = False
for w in s:
  if(w.isupper()):
      flag = True
if(flag == True):
  print("found")
# Out:
# found

# %%
names = 'Joe, David, Mark, Tom, Chris, Robert'
lst = names.split(',')
print(lst)
# Out:
# ['Joe', ' David', ' Mark', ' Tom', ' Chris', ' Robert']

# %%
s = ""
text = 'this is some text'
lst = text.split(' ')
for w  in lst:
  s+=w+"aye "
print(s)
# Out:
# thisaye isaye someaye textaye

# %%
s = input()
if("fye" in s):
  print("True")
else:
  print("False")
# Out:
# awfye
# True

# %%
ext = '%p34@y!*-*!t68h#&on404'
s = ""
for ch in ext:
  if ch>='a' and ch<='z':
    s+=ch
print(s)
# Out:
# python

# %%
s = "this is a paragraph which is written just for the purpose of providing content to let the average word length be calculated"
lst = s.split(" ")
sum = 0
for w in lst:
  sum += len(w)
print(sum / len(lst))
# Out:
# 4.636363636363637

# %%
print("to move to newline '\\n' is used.")
# Out:
# to move to newline '\n' is used.

# %%
print("the variable is 15")
# Out:
# the variable is 15

# %%
s1 = 'python '
s2 = 'is '
s3 = 'great.'
print(s1+s2+s3)
# Out:
# python is great.

# %%
print("#"*20)
# Out:
# ####################

# %%
for i in range(1,10):
  print(str(i)+".")
# Out:
# 1.
# 2.
# 3.
# 4.
# 5.
# 6.
# 7.
# 8.
# 9.
